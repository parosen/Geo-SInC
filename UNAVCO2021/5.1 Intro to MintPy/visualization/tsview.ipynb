# %% [markdown]
# ## Plot displacement time-series in a notebook ##
#
# This notebook calls `tsview.py` in MintPy for interactive time-series visualization. The corresponding command line usage is print out for the reference.

# %%
# %matplotlib notebook
import os
import matplotlib.pyplot as plt
from mintpy.tsview import timeseriesViewer

# visualization functions
def tsview(fname, yx=None, figsize_img=[5, 4], figsize_pts=[5, 2]):
    """Plot input file using tsview.py"""
    cmd = 'tsview.py {} --ms 4 --noverbose'.format(fname)
    if yx is not None:
        cmd += ' --yx {} {}'.format(yx[0], yx[1])
    obj = timeseriesViewer(cmd)
    obj.configure()
    obj.figsize_img = figsize_img
    obj.figsize_pts = figsize_pts
    obj.plot()
    return obj

# %%
ts_file = os.path.expanduser('~/data/SanFranSenDT42/mintpy/timeseries_ERA5_demErr.h5')
tsview(ts_file, yx=(840, 796), figsize_img=[4, 5])
# Out:
# tsview.py /home/jovyan/data/SanFranSenDT42/mintpy/timeseries_ERA5_demErr.h5 --ms 4 --noverbose --yx 840 796
# No lookup table info range/lat found in files.
# estimate deformation model with the following assumed time functions:
#     polynomial : 1
#     periodic   : []
#     step       : []
#     exp        : {}
#     log        : {}
# reading slice 154/154...
# <img src="data:image/png;base64,..." width="400">
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# Try the tsview.py in command line in your terminal for more advanced / customized features.

# %%
# !tsview.py -h
# Out:
# tsview.py -h
# usage: tsview.py [-h] [--label [FILE_LABEL [FILE_LABEL ...]]]
#                  [--ylim YMIN YMAX] [--tick-right] [-l LOOKUP_FILE] [-n NUM]
#                  [--error ERROR_FILE] [--start-date START_DATE]
#                  [--end-date END_DATE]
#                  [--exclude [EX_DATE_LIST [EX_DATE_LIST ...]]] [--zf]
#                  [--off OFFSET] [--noverbose] [--nomodel]
#                  [--plot-model-conf-int] [--poly POLYNOMIAL]
#                  [--periodic PERIODIC [PERIODIC ...]] [--step STEP [STEP ...]]
#                  [--exp EXP [EXP ...]] [--log LOG [LOG ...]] [--yx Y X]
#                  [--lalo LAT LON] [--marker MARKER] [--ms MARKER_SIZE]
#                  [--lw LINEWIDTH] [--ew EDGE_WIDTH] [-v VMIN VMAX] [-u UNIT]
#                  [--wrap] [--wrap-range MIN MAX] [--flip-lr] [--flip-ud]
#                  [--noflip] [--multilook-num NUM] [--nomultilook]
#                  [--alpha TRANSPARENCY] [-d DEM_FILE] [--dem-noshade]
# ...
